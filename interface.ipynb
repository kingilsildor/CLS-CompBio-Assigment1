# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data/Kinetics.csv")
print(df.shape)
df.head()
# Out:
# (300, 3)
#          S1      Rate    S2
# 0  0.010000  0.076923  0.05
# 1  0.030204  0.158458  0.05
# 2  0.050408  0.200650  0.05
# 3  0.070612  0.226440  0.05
# 4  0.090816  0.243836  0.05

# %%
plt.figure(figsize=(10, 6))
for s2, group in df[df["S2"] <= 1.0].groupby("S2"):
    inv_S1 = 1 / group["S1"]
    inv_Rate = 1 / group["Rate"]
    plt.plot(inv_S1, inv_Rate, "o-", label=f"1/[S2] = {1 / s2:.1f} mM⁻¹")

plt.xlabel("1/[S1] (mM⁻¹)")
plt.ylabel("1/Rate (s/mM)")
plt.title("Lineweaver-Burk Plot for different values of [S2]")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
